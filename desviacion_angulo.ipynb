# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.array([0.1]*50)
b = np.sin(np.linspace(0,4,50)) + np.random.uniform(-0.1,0.1,50)
c = np.cos(np.linspace(2,6,50)) + np.random.uniform(-0.1,0.1,50)
d = [i - np.random.uniform(0,0.8) for i in np.linspace(0,1,50)]

# %%
fig,ax = plt.subplots(1,1,figsize=(15,7),dpi=120)
ax.plot(np.linspace(0,50,50),a, marker='o', linestyle='dashed', label='Inversión a')
ax.plot(np.linspace(0,50,50),a, marker='o', linestyle='dashed', label='Inversión b')
ax.plot(np.linspace(0,50,50),a, marker='o', linestyle='dashed', label='Inversión c')
ax.plot(np.linspace(0,50,50),a, marker='o', linestyle='dashed', label='Inversión d')
ax.set_xlabel('Tiempo')
ax.set_ylabel('Fracción de retorno')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-487a62e92bdf> in <module>()
#       1 fig,ax = plt.subplots(1,1,figsize=(15,7),dpi=120)
# ----> 2 ax.plot(np.linspace(0,50,50),a, marker='o', linestyle='dashed', label='Inversión a')
#       3 ax.plot(np.linspace(0,50,50),a, marker='o', linestyle='dashed', label='Inversión b')
#       4 ax.plot(np.linspace(0,50,50),a, marker='o', linestyle='dashed', label='Inversión c')
#       5 ax.plot(np.linspace(0,50,50),a, marker='o', linestyle='dashed', label='Inversión d')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (100,)

# %%
I = np.array([a,b,c,d])

# %%
M = np.array([np.mean(x) for x in I])
S = np.array([np.std(x) for x in I])

# %%
fig,ax = plt.subplots(1,1,figsize=(7,7,),dpi=120)
ax.scatter(S[0],M[0], linestyle='dashed', label='Inversión a')
ax.scatter(S[1],M[1], linestyle='dashed', label='Inversión b')
ax.scatter(S[2],M[2], linestyle='dashed', label='Inversión c')
ax.scatter(S[3],M[3], linestyle='dashed', label='Inversión d')
ax.set_xlabel('Riesgo')
ax.set_ylabel('Retorno esperado')
ax.legend()
plt.show()

# %% [markdown]
# ## Angulos entre Vectores y Correlación

# %%
def demean(a):
  return a - np.mean(a)*np.array([1]*len(a))

# %%
def correlacion(a,b):
  a,b = demean(a),demean(b)
  return (a@b)/(np.linalg.norm(a)*np.linalg.norm(b))

# %%
a = np.sin(np.linspace(0,6,100)) + np.random.uniform(-0.4,0.4,100)
b = np.sin(np.linspace(0,6,100)) + np.random.uniform(-0.4,0.4,100)

# %%
print('La correlación entre a y b es: ', correlacion(a,b))
# Out:
# La correlación entre a y b es:  0.9105474387822975

# %%
fig, ax = plt.subplots(1,1,figsize=(7,7),dpi=120)
ax.plot(np.linspace(0,6,100),a, label = 'Serie A', marker='o', linestyle='dashed')
ax.plot(np.linspace(0,6,100),b, label = 'Serie B', marker='o', linestyle='dashed')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(7,7),dpi=120)
ax.scatter(a,b)
ax.set_xlabel(r'$a_{i}$')
ax.set_ylabel(r'$b_{i}$')
plt.show()
